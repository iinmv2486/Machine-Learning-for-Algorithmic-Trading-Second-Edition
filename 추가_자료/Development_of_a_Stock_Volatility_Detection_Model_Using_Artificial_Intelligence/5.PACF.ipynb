# %% [markdown]
# ACF/PACF 분석 수행

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import matplotlib.pyplot as plt

fig, ax = plt.subplots(2, 1, figsize=(12, 6))
plot_acf(df['Price'].dropna(), lags=50, ax=ax[0])
ax[0].set_title("Autocorrelation Function (ACF)")
plot_pacf(df['Price'].dropna(), lags=50, ax=ax[1])
ax[1].set_title("Partial Autocorrelation Function (PACF)")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 5
#       2 import matplotlib.pyplot as plt
#       4 fig, ax = plt.subplots(2, 1, figsize=(12, 6))
# ----> 5 plot_acf(df['Price'].dropna(), lags=50, ax=ax[0])
#       6 ax[0].set_title("Autocorrelation Function (ACF)")
#       7 plot_pacf(df['Price'].dropna(), lags=50, ax=ax[1])
#
# NameError: name 'df' is not defined
